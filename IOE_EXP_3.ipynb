# %% [markdown]
# <a href="https://colab.research.google.com/github/192512041simats-hari/IOE-AND-AI-SYSTEM/blob/main/IOE_EXP_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt

num_slots = 100

slot_number = []
status = []

vacant_slots = []
occupied_slots = []

for i in range(1, num_slots + 1):

    # 70% Occupied, 30% Vacant
    if random.random() < 0.7:
        s = "Occupied"
        occupied_slots.append(i)
    else:
        s = "Vacant"
        vacant_slots.append(i)

    slot_number.append(i)
    status.append(s)

# Create DataFrame
df = pd.DataFrame({
    "Parking Slot": slot_number,
    "Status": status
})

print(df)

print("\n========== PARKING SUMMARY ==========")
print("Total Slots      :", num_slots)
print("Occupied Slots   :", len(occupied_slots))
print("Vacant Slots     :", len(vacant_slots))

print("\nVacant Slot Numbers:")
print(vacant_slots)

print("\nOccupied Slot Numbers:")
print(occupied_slots)

if len(occupied_slots) > 85:
    print("\nParking Status : HIGH TRAFFIC")
else:
    print("\nParking Status : NORMAL")

# Save CSV
df.to_csv("parking_slots.csv", index=False)

# Plot
plt.figure(figsize=(14,4))

colors = ['red' if x=="Occupied" else 'green' for x in status]

plt.bar(slot_number, [1]*num_slots, color=colors)

plt.xlabel("Parking Slot Number")
plt.title("Smart Parking Occupancy")
plt.yticks([])

plt.show()
# Out:
#     Parking Slot    Status
# 0              1  Occupied
# 1              2    Vacant
# 2              3  Occupied
# 3              4  Occupied
# 4              5  Occupied
# ..           ...       ...
# 95            96    Vacant
# 96            97  Occupied
# 97            98    Vacant
# 98            99  Occupied
# 99           100  Occupied
#
# [100 rows x 2 columns]
#
# ========== PARKING SUMMARY ==========
# Total Slots      : 100
# Occupied Slots   : 66
# Vacant Slots     : 34
#
# Vacant Slot Numbers:
# [2, 6, 8, 10, 15, 16, 17, 18, 25, 30, 32, 34, 38, 45, 47, 48, 50, 52, 53, 58, 59, 60, 61, 71, 72, 75, 76, 80, 83, 84, 85, 94, 96, 98]
#
# Occupied Slot Numbers:
# [1, 3, 4, 5, 7, 9, 11, 12, 13, 14, 19, 20, 21, 22, 23, 24, 26, 27, 28, 29, 31, 33, 35, 36, 37, 39, 40, 41, 42, 43, 44, 46, 49, 51, 54, 55, 56, 57, 62, 63, 64, 65, 66, 67, 68, 69, 70, 73, 74, 77, 78, 79, 81, 82, 86, 87, 88, 89, 90, 91, 92, 93, 95, 97, 99, 100]
#
# Parking Status : NORMAL
